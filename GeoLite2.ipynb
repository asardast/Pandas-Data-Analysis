# %%
import pandas as pd

df= pd.read_csv('GeoLite2-Country-Locations-fr.csv', keep_default_na=False)

df.head()
# Out:
#    geoname_id locale_code continent_code continent_name country_iso_code  \
# 0       49518          fr             AF        Afrique               RW
# 1       51537          fr             AF        Afrique               SO
# 2       69543          fr             AS           Asie               YE
# 3       99237          fr             AS           Asie               IQ
# 4      102358          fr             AS           Asie               SA
#
#       country_name  is_in_european_union
# 0           Rwanda                     0
# 1          Somalie                     0
# 2            Yémen                     0
# 3             Irak                     0
# 4  Arabie saoudite                     0

# %%
import matplotlib.pyplot as plt


continent_counts = df.groupby('continent_name').size().sort_values(ascending=True)
continent_counts.plot(kind='barh', color='skyblue')
plt.show()
